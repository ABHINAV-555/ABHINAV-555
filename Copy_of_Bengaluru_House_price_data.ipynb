# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHINAV-555/ABHINAV-555/blob/main/Copy_of_Bengaluru_House_price_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'/content/Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# 1-some value is 2bhk and some value is 4 bradroom
# 2-society have nan value

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.sample()
# Out:
#        area_type availability        location       size  society total_sqft  \
# 6250  Plot  Area       18-Mar  Kuvempu Layout  3 Bedroom  LGeete        2200
#
#       bath  balcony  price
# 6250   4.0      2.0  160.0

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df['location'].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df['location'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319    False
# Name: location, Length: 13320, dtype: bool

# %%
df[df['location'].isnull()]
# Out:
#                 area_type   availability location   size  society total_sqft  \
# 568  Super built-up  Area  Ready To Move      NaN  3 BHK  Grare S       1600
#
#      bath  balcony  price
# 568   3.0      2.0   86.0

# %%
for i in df.columns:
  print(df[i].value_counts())
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: availability, Length: 81, dtype: int64
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64
# 2 BHK         5199
# ...

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.shape
# Out:
# (13320, 9)

# %%
df=df.drop(columns='society')

# %%
df=df.drop(columns=['availability','balcony'])

# %%
df.shape
# Out:
# (13320, 6)

# %%
df.describe()
# Out:
#                bath         price
# count  13247.000000  13320.000000
# mean       2.692610    112.565627
# std        1.341458    148.971674
# min        1.000000      8.000000
# 25%        2.000000     50.000000
# 50%        2.000000     72.000000
# 75%        3.000000    120.000000
# max       40.000000   3600.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   location    13319 non-null  object
#  2   size        13304 non-null  object
#  3   total_sqft  13320 non-null  object
#  4   bath        13247 non-null  float64
#  5   price       13320 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 624.5+ KB

# %%
df.isnull().sum()
# Out:
# area_type      0
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df['location'].value_counts()
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
df['location'].fillna('Whitefield',inplace=True)

# %%
df['location'].value_counts()
# Out:
# Whitefield                        541
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
df['size'].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: size, dtype: int64

# %%
df['size'].isna().sum()
# Out:
# 16

# %%
df['size'].fillna('2 BHK',inplace=True)

# %%
df['size'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   location    13320 non-null  object
#  2   size        13320 non-null  object
#  3   total_sqft  13320 non-null  object
#  4   bath        13247 non-null  float64
#  5   price       13320 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 624.5+ KB

# %%
df['bath'].value_counts()
# Out:
# 2.0     6908
# 3.0     3286
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 13.0       3
# 11.0       3
# 16.0       2
# 27.0       1
# 40.0       1
# 15.0       1
# 14.0       1
# 18.0       1
# Name: bath, dtype: int64

# %%
df['bath'].isna().sum()
# Out:
# 73

# %%
df[df['bath'].isna()]
# Out:
#                   area_type        location       size   total_sqft  bath  \
# 56           Built-up  Area     Devanahalli  4 Bedroom  3010 - 3410   NaN
# 81           Built-up  Area     Hennur Road  4 Bedroom  2957 - 3450   NaN
# 224    Super built-up  Area     Devanahalli      3 BHK  1520 - 1740   NaN
# 344    Super built-up  Area  Kanakpura Road      1 BHK          525   NaN
# 579              Plot  Area  Sarjapur  Road      2 BHK  1200 - 2400   NaN
# ...                     ...             ...        ...          ...   ...
# 11496  Super built-up  Area  Kanakpura Road      1 BHK          525   NaN
# 11569            Plot  Area      Hosur Road      2 BHK         1350   NaN
# 12768        Built-up  Area    Bettahalsoor  5 Bedroom         3210   NaN
# 12861  Super built-up  Area        KR Puram      4 BHK  2204 - 2362   NaN
# 13240  Super built-up  Area     Devanahalli      1 BHK  1020 - 1130   NaN
#
#          price
# 56     192.000
# 81     224.500
# 224     74.820
# ...

# %%
df['bath'].fillna(df['bath'].median(),inplace=True)

# %%
df['bath'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   13320 non-null  object
#  1   location    13320 non-null  object
#  2   size        13320 non-null  object
#  3   total_sqft  13320 non-null  object
#  4   bath        13320 non-null  float64
#  5   price       13320 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 624.5+ KB

# %%
df
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath   price
# 0       2.0   39.07
# ...

# %%
df['size'].str.split()
# Out:
# 0            [2, BHK]
# 1        [4, Bedroom]
# 2            [3, BHK]
# 3            [3, BHK]
# 4            [2, BHK]
#              ...
# 13315    [5, Bedroom]
# 13316        [4, BHK]
# 13317        [2, BHK]
# 13318        [4, BHK]
# 13319        [1, BHK]
# Name: size, Length: 13320, dtype: object

# %%
for i in  [2, 'BHK']:
  if type(i)==int:
    print(i)
# Out:
# 2

# %%
df['size'].str.split().str[0]
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: size, Length: 13320, dtype: object

# %%
type(df['size'].str.split().str[0])
# Out:
# pandas.core.series.Series

# %%
df['size'].str.split().str[0].astype('i')
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: size, Length: 13320, dtype: int32

# %%
df['BHK']=df['size'].str.split().str[0].astype('i')

# %%
df
# Out:
#                   area_type                  location       size total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK       1056
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom       2600
# 2            Built-up  Area               Uttarahalli      3 BHK       1440
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK       1521
# 4      Super built-up  Area                  Kothanur      2 BHK       1200
# ...                     ...                       ...        ...        ...
# 13315        Built-up  Area                Whitefield  5 Bedroom       3453
# 13316  Super built-up  Area             Richards Town      4 BHK       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK       1141
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK       4689
# 13319  Super built-up  Area              Doddathoguru      1 BHK        550
#
#        bath   price  BHK
# 0       2.0   39.07    2
# ...

# %%
df.describe()
# Out:
#                bath         price           BHK
# count  13320.000000  13320.000000  13320.000000
# mean       2.688814    112.565627      2.802778
# std        1.338754    148.971674      1.294496
# min        1.000000      8.000000      1.000000
# 25%        2.000000     50.000000      2.000000
# 50%        2.000000     72.000000      3.000000
# 75%        3.000000    120.000000      3.000000
# max       40.000000   3600.000000     43.000000

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def convert (x):
 tem=x.split('-')

 if len(tem)==2:
  return(float(tem[0])+float(tem[1]))//2

 try:
  return float(x)

 except:
  return None

# %%
df['total_sqft'].apply(convert)
# Out:
# 0        1056.0
# 1        2600.0
# 2        1440.0
# 3        1521.0
# 4        1200.0
#           ...
# 13315    3453.0
# 13316    3600.0
# 13317    1141.0
# 13318    4689.0
# 13319     550.0
# Name: total_sqft, Length: 13320, dtype: float64

# %%
df['total_sqft']=df['total_sqft'].apply(convert)

# %%
df['total_sqft'].unique()
# Out:
# array([1056., 2600., 1440., ..., 2758.,  774., 4689.])

# %%
df.describe()
# Out:
#          total_sqft          bath         price           BHK
# count  13274.000000  13320.000000  13320.000000  13320.000000
# mean    1559.623410      2.688814    112.565627      2.802778
# std     1238.404503      1.338754    148.971674      1.294496
# min        1.000000      1.000000      8.000000      1.000000
# 25%     1100.000000      2.000000     50.000000      2.000000
# 50%     1276.000000      2.000000     72.000000      3.000000
# 75%     1680.000000      3.000000    120.000000      3.000000
# max    52272.000000     40.000000   3600.000000     43.000000

# %%
df.head()
# Out:
#               area_type                  location       size  total_sqft  \
# 0  Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1            Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2        Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3  Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4  Super built-up  Area                  Kothanur      2 BHK      1200.0
#
#    bath   price  BHK
# 0   2.0   39.07    2
# 1   5.0  120.00    4
# 2   2.0   62.00    3
# 3   3.0   95.00    3
# 4   2.0   51.00    2

# %%
df['price_squre']=df['price']*100000/df['total_sqft']

# %%
df
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13316  Super built-up  Area             Richards Town      4 BHK      3600.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK      4689.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
#        bath   price  BHK   price_squre
# ...

# %%
df.describe()
# Out:
#          total_sqft          bath         price           BHK   price_squre
# count  13274.000000  13320.000000  13320.000000  13320.000000  1.327400e+04
# mean    1559.623410      2.688814    112.565627      2.802778  7.907513e+03
# std     1238.404503      1.338754    148.971674      1.294496  1.064296e+05
# min        1.000000      1.000000      8.000000      1.000000  2.678298e+02
# 25%     1100.000000      2.000000     50.000000      2.000000  4.266865e+03
# 50%     1276.000000      2.000000     72.000000      3.000000  5.434306e+03
# 75%     1680.000000      3.000000    120.000000      3.000000  7.311746e+03
# max    52272.000000     40.000000   3600.000000     43.000000  1.200000e+07

# %%
df['location'].value_counts()
# Out:
# Whitefield                        541
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
df['location']=df['location'].apply(lambda x:x.strip())

# %%
df['location'].value_counts()
# Out:
# Whitefield                        542
# Sarjapur  Road                    399
# Electronic City                   304
# Kanakpura Road                    273
# Thanisandra                       237
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1294, dtype: int64

# %%
l_count=df['location'].value_counts()
l_count_10=l_count[l_count<=10]
l_count_10
# Out:
# Dairy Circle                      10
# Nagappa Reddy Layout              10
# Basapura                          10
# 1st Block Koramangala             10
# Sector 1 HSR Layout               10
#                                   ..
# Bapuji Layout                      1
# 1st Stage Radha Krishna Layout     1
# BEML Layout 5th stage              1
# singapura paradise                 1
# Abshot Layout                      1
# Name: location, Length: 1053, dtype: int64

# %%
df['location'].apply(lambda x: 'low_grade' if x in l_count_10 else x)
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316                   low_grade
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13320, dtype: object

# %%
df['location']=df['location'].apply(lambda x: 'low_grade' if x in l_count_10 else x)

# %%
df
# Out:
#                   area_type                  location       size  total_sqft  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK      1056.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom      2600.0
# 2            Built-up  Area               Uttarahalli      3 BHK      1440.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK      1521.0
# 4      Super built-up  Area                  Kothanur      2 BHK      1200.0
# ...                     ...                       ...        ...         ...
# 13315        Built-up  Area                Whitefield  5 Bedroom      3453.0
# 13316  Super built-up  Area                 low_grade      4 BHK      3600.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK      1141.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK      4689.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK       550.0
#
#        bath   price  BHK   price_squre
# ...

# %%
df.to_csv('clenned data bengaluru house data')
